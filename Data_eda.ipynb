# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns

# %%
df = pd.read_csv('DataAnalyst_Cleaned.csv')
df
# Out:
#                                               Job Title Salary Estimate  \
# 0     Data Analyst, Center on Immigration and Justic...          37-66
# 1                                  Quality Data Analyst          37-66
# 2     Senior Data Analyst, Insights & Analytics Team...          37-66
# 3                                          Data Analyst          37-66
# 4                                Reporting Data Analyst          37-66
# ...                                                 ...             ...
# 2247  RQS - IHHA - 201900004460 -1q Data Security An...         78-104
# 2248              Senior Data Analyst (Corporate Audit)         78-104
# 2249  Technical Business Analyst (SQL, Data analytic...         78-104
# 2250                Data Analyst 3, Customer Experience         78-104
# 2251                        Senior Quality Data Analyst         78-104
#
#                                         Job Description  Rating  \
# ...

# %%
df.head()
# Out:
#                                            Job Title Salary Estimate  \
# 0  Data Analyst, Center on Immigration and Justic...          37-66
# 1                               Quality Data Analyst          37-66
# 2  Senior Data Analyst, Insights & Analytics Team...          37-66
# 3                                       Data Analyst          37-66
# 4                             Reporting Data Analyst          37-66
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                          Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice  New York, NY  New York, NY
# ...

# %%
df['State'] = df['State'].apply(lambda x: 'CO' if x == ' Arapahoe' else x)
df
# Out:
#                                               Job Title Salary Estimate  \
# 0     Data Analyst, Center on Immigration and Justic...          37-66
# 1                                  Quality Data Analyst          37-66
# 2     Senior Data Analyst, Insights & Analytics Team...          37-66
# 3                                          Data Analyst          37-66
# 4                                Reporting Data Analyst          37-66
# ...                                                 ...             ...
# 2247  RQS - IHHA - 201900004460 -1q Data Security An...         78-104
# 2248              Senior Data Analyst (Corporate Audit)         78-104
# 2249  Technical Business Analyst (SQL, Data analytic...         78-104
# 2250                Data Analyst 3, Customer Experience         78-104
# 2251                        Senior Quality Data Analyst         78-104
#
#                                         Job Description  Rating  \
# ...

# %%
df['State'].value_counts()
# Out:
# State
#  CA    626
#  TX    394
#  NY    345
#  IL    164
#  PA    114
#  AZ     97
#  NC     90
#  CO     88
#  NJ     86
#  WA     53
#  VA     48
#  OH     35
#  UT     33
#  FL     27
#  IN     23
#  DE     11
# CO       8
#  GA      4
#  KS      3
#  SC      3
# Name: count, dtype: int64

# %%
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0       7057
# 1       4702
# 2       4688
# 3       5249
# 4       3376
#         ...
# 2247     497
# 2248    4214
# 2249    2372
# 2250    4256
# 2251    3389
# Name: desc_len, Length: 2252, dtype: int64

# %%
df['Competitors_cnt'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df['Competitors_cnt']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 2247    0
# 2248    3
# 2249    0
# 2250    0
# 2251    3
# Name: Competitors_cnt, Length: 2252, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Min Salary', 'Max Salary', 'Avg Salary', 'State',
#        'Programming Lang', 'Age', 'same_state', 'desc_len', 'Competitors_cnt'],
#       dtype='object')

# %%
df['Rating'].hist()
# Out:
# <Axes: >

# %%
df['Industry'].hist()
# Out:
# <Axes: >

# %%
df['Salary Estimate'].hist()
# Out:
# <Axes: >

# %%
df['Avg Salary'].hist()
# Out:
# <Axes: >

# %%
df['Age'].hist()
# Out:
# <Axes: >

# %%
df['desc_len'].hist()
# Out:
# <Axes: >

# %%
df.boxplot(column=['Rating', 'Avg Salary'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['Rating'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['Age'])
# Out:
# <Axes: >

# %%
df[['Age', 'Rating', 'Avg Salary', 'desc_len']].corr()
# Out:
#                  Age    Rating  Avg Salary  desc_len
# Age         1.000000  0.201040   -0.074710  0.255342
# Rating      0.201040  1.000000    0.004301 -0.018666
# Avg Salary -0.074710  0.004301    1.000000 -0.033643
# desc_len    0.255342 -0.018666   -0.033643  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['Age', 'Rating', 'Avg Salary', 'desc_len']].corr(), vmax=3, center=0, cmap=cmap,
            square=True, linewidths=5, cbar_kws={"shrink":.5})
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Min Salary', 'Max Salary', 'Avg Salary', 'State',
#        'Programming Lang', 'Age', 'same_state', 'desc_len', 'Competitors_cnt'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors_cnt', 'State',
       'Programming Lang', 'Age']]

# %%
for i in df_cat:
  cat_num = df_cat[i].value_counts()
  print("Graph for %s: Total = %d" % (i, len(cat_num)))
  chart = sns.barplot(x=cat_num.index, y=cat_num)
  chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
  plt.show()
# Out:
# Graph for Location: Total = 253
# <ipython-input-39-13d8e08d7fba>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
# Graph for Headquarters: Total = 483
# <ipython-input-39-13d8e08d7fba>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
# Graph for Size: Total = 9
# <ipython-input-39-13d8e08d7fba>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
# Graph for Type of ownership: Total = 15
# <ipython-input-39-13d8e08d7fba>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
# Graph for Industry: Total = 89
# <ipython-input-39-13d8e08d7fba>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %%
for i in df_cat[['Location', 'Headquarters', 'Industry']].columns:
  cat_num = df_cat[i].value_counts()[:20]
  print("Graph for %s: Total = %d" % (i, len(cat_num)))
  chart = sns.barplot(x=cat_num.index, y=cat_num)
  chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
  plt.show()
# Out:
# Graph for Location: Total = 20
# <ipython-input-41-9acbcaa9cd9c>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
# Graph for Headquarters: Total = 20
# <ipython-input-41-9acbcaa9cd9c>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
# Graph for Industry: Total = 20
# <ipython-input-41-9acbcaa9cd9c>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Min Salary', 'Max Salary', 'Avg Salary', 'State',
#        'Programming Lang', 'Age', 'same_state', 'desc_len', 'Competitors_cnt'],
#       dtype='object')

# %%
pd.pivot_table(df, index='Programming Lang', values='Avg Salary').sort_values('Avg Salary', ascending=False)
# Out:
#                             Avg Salary
# Programming Lang
# python,tableau               83.789474
# python,sql,tableau           77.425993
# python                       76.812500
# tableau                      72.719697
# python,sql,powerbi           72.571429
# sql,tableau                  72.051887
# python,sql                   71.957692
# tableau,powerbi              70.000000
# sql                          69.737347
# sql,tableau,powerbi          66.380000
# sql,powerbi                  63.970588
# powerbi                      63.250000
# python,sql,tableau,powerbi   59.294118
# python,tableau,powerbi       40.000000

# %%
pd.pivot_table(df, index='State', values='Avg Salary').sort_values('Avg Salary', ascending=False)
# Out:
#        Avg Salary
# State
#  CA     88.432109
#  IL     78.310976
#  CO     73.619318
#  NJ     73.000000
# CO      72.250000
#  NY     71.411594
#  AZ     70.788660
#  SC     68.333333
#  NC     68.111111
#  VA     65.187500
#  WA     64.754717
#  PA     61.728070
#  DE     59.727273
#  TX     58.751269
#  FL     51.851852
#  KS     51.500000
#  IN     47.500000
#  OH     45.200000
#  GA     44.000000
#  UT     37.530303

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Min Salary', 'Max Salary', 'Avg Salary', 'State',
#        'Programming Lang', 'Age', 'same_state', 'desc_len', 'Competitors_cnt'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'Competitors_cnt', 'Programming Lang', 'desc_len', 'Type of ownership', 'Avg Salary']]

# %%
for i in df_pivots.columns:
  if i != 'Avg Salary':
    print(i)
    print(pd.pivot_table(df_pivots, index=i, values='Avg Salary').sort_values('Avg Salary', ascending=False))
# Out:
# Rating
#         Avg Salary
# Rating
#  2.2     95.666667
#  4.4     82.366667
#  1.7     82.000000
#  1.6     80.000000
#  2.0     79.750000
#  2.4     77.350000
#  4.5     76.925532
#  3.2     76.901099
#  2.1     76.625000
#  4.0     76.232558
#  3.9     75.210714
#  4.6     74.760870
#  4.1     74.424370
#  2.3     73.888889
#  4.2     73.159574
#  4.8     72.913793
# -1.0     72.867647
#  2.5     72.781250
#  3.4     72.158416
#  5.0     72.125954
#  3.7     71.803030
#  3.3     71.440367
#  4.7     71.000000
#  3.0     70.982456
#  3.8     69.534615
#  3.6     69.207407
#  3.1     68.801471
#  4.3     68.172727
#  2.8     67.825581
#  3.5     67.240000
#  2.9     66.887500
#  2.6     65.821429
#  1.0     64.250000
#  2.7     62.780000
#  4.9     61.470588
#  1.9     61.250000
#  1.8     58.250000
# Industry
#                                     Avg Salary
# Industry
# Drug & Health Stores                 95.250000
# Education Training Services          92.833333
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'Programming Lang', values='Avg Salary', aggfunc='count')
# Out:
# Programming Lang                  powerbi  python  python,sql  \
# Revenue
# $1 to $2 billion (USD)                NaN     1.0        12.0
# $1 to $5 million (USD)                NaN     3.0        14.0
# $10 to $25 million (USD)              NaN     2.0        10.0
# $10+ billion (USD)                    1.0    15.0        18.0
# $100 to $500 million (USD)            1.0     8.0        24.0
# $2 to $5 billion (USD)                NaN     1.0        16.0
# $25 to $50 million (USD)              1.0     2.0        12.0
# $5 to $10 billion (USD)               NaN     1.0         5.0
# $5 to $10 million (USD)               NaN     2.0         9.0
# $50 to $100 million (USD)             NaN     1.0        13.0
# $500 million to $1 billion (USD)      1.0     2.0         7.0
# -1                                    2.0     2.0        15.0
# Less than $1 million (USD)            NaN     1.0        14.0
# Unknown / Non-Applicable              2.0    15.0        91.0
#
# ...

# %%
# !pip install wordcloud
# !pip install nltk

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
  """ remove punctuation and stop words """
  filtered = []
  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(text)
  for w in word_tokens:
    if w not in stop_words and w.isalpha():
      filtered.append(w.lower())
  return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])


wc = WordCloud(background_color="white", random_state=1, stopwords=STOPWORDS, max_words=2000, width=800, height=1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
